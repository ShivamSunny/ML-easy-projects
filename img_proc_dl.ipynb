# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivamSunny/ML-easy-projects/blob/main/img_proc_dl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# getting an image using web get

# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2024-09-17 10:16:15--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 108.156.152.26, 108.156.152.104, 108.156.152.102, ...
# Connecting to tractive.com (tractive.com)|108.156.152.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg’
#
# puppy-care-guide-fo 100%[===================>] 110.91K   611KB/s    in 0.2s
#
# 2024-09-17 10:16:16 (611 KB/s) - ‘puppy-care-guide-for-new-parents.jpg’ saved [113570/113570]

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/content/dogs.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
img.ndim
# Out:
# 3

# %%
print(img)
# Out:
# [[[ 22  22  12]
#   [ 22  22  12]
#   [ 24  24  12]
#   ...
#   [ 31  44  16]
#   [ 27  39  15]
#   [ 24  36  12]]
#
#  [[ 21  21  13]
#   [ 22  22  12]
#   [ 23  23  13]
#   ...
#   [ 29  42  14]
#   [ 26  38  14]
#   [ 22  34  10]]
#
#  [[ 21  20  15]
#   [ 21  21  13]
#   [ 23  23  13]
#   ...
#   [ 27  40  12]
#   [ 23  35  11]
#   [ 20  32   8]]
#
#  ...
#
#  [[ 88 106   6]
#   [ 88 106   4]
#   [ 88 106   4]
#   ...
#   [ 96 111  16]
#   [ 95 111  13]
#   [ 95 111  13]]
#
#  [[ 87 105   6]
#   [ 87 105   5]
#   [ 87 105   5]
#   ...
#   [ 94 109  14]
#   [ 94 109  14]
#   [ 94 109  14]]
#
#  [[ 86 104   5]
#   [ 86 104   5]
#   [ 86 104   4]
#   ...
#   [ 94 109  14]
#   [ 93 108  13]
#   [ 93 108  13]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/dogs.jpg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/dogs.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image
# Out:
# array([[19, 19, 20, ..., 34, 30, 27],
#        [19, 19, 20, ..., 32, 29, 25],
#        [19, 19, 20, ..., 30, 26, 23],
#        ...,
#        [74, 73, 73, ..., 81, 80, 80],
#        [73, 73, 73, ..., 79, 79, 79],
#        [72, 72, 72, ..., 79, 78, 78]], dtype=uint8)

# %%
grayscale_image.shape
# Out:
# (168, 300)

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
